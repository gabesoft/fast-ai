# %%
# %matplotlib inline

# %%
# %pwd
# Out:
# '/home/gabe/work/fast-ai/lesson1/nbs'

# %% [markdown]
# ### Import libraries

# %%
import os
import sys
import json
import numpy as np
from glob import glob
from matplotlib import pyplot as plt
from importlib import reload

# %% [markdown]
# ### Setup libraries

# %%
np.set_printoptions(precision=4, linewidth=100)
sys.path.append(r'../src')

# %% [markdown]
# ### Load local modules

# %%
from datasetup import *

# %% [markdown]
# ### Global constants

# %%
data_dir = '../data'

# %% [markdown]
# ### Setup data

# %%
create_validation_set(data_dir)

# %%
create_sample_set(data_dir)

# %%
move_files_to_label_dirs(data_dir)

# %%
create_test_set(data_dir)

# %%
import time

time.time()

time.strftime("%Y.%m.%d.%H")
# Out:
# '2017.10.01.12'

# %%
from PIL import Image
from trainhelper import *

test_dir = data_dir + '/test'

batches = get_batches(test_dir)

filenames = batches.filenames

print(filenames[:5])

Image.open(test_dir + '/' + filenames[2])
# Out:
# Found 12500 images belonging to 1 classes.
# ['unknown/532.jpg', 'unknown/10860.jpg', 'unknown/5928.jpg', 'unknown/11799.jpg', 'unknown/9775.jpg']
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x278 at 0x7FB3450CEDA0>
